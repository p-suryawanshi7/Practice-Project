# %% [markdown]
# # Abalone Case Study

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the DATASET

# %%
Abalone_case=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")

# %%
Abalone_case.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# # Checking Column Names

# %%
Abalone_case.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # Checking Data Type of Data

# %%
Abalone_case.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# # Checking for Null Values

# %%
Abalone_case.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# #### Obtaining Age from 'Ring' Column, Age = Rings +1.5 years.

# %%
Abalone_case['Age'] = Abalone_case['Rings'] + 1.5
Abalone_case['Age']
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: Age, Length: 4177, dtype: float64

# %% [markdown]
# ## DATA ANALYSIS

# %% [markdown]
# ### Barplot:

# %%
fig = plt.figure(figsize = (7,5))
sns.barplot(x = 'Sex', y = 'Rings', data = Abalone_case)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Rings'>

# %% [markdown]
# # Normal Distribution Curve:

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Shucked weight'])
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Viscera weight'])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %%
fig = plt.figure(figsize = (7,5))
sns.distplot(Abalone_case['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## The Normal Distribution shows that the data is Skewed

# %%
sns.pairplot(Abalone_case)

# %%
sns.histplot(Abalone_case)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
plt.figure(figsize=(30,7))
Abalone_case.corr()['Rings'].sort_values(ascending=True).drop(['Rings']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=18)
plt.ylabel('Target',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# It shows good correlation with Target Variable

# %% [markdown]
# ## Checking Skewness

# %%
Abalone_case.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# Age               1.114102
# dtype: float64

# %% [markdown]
# Skewness threshold taken is +/-0.65. Columns which are having skewness: Height, Shucked weight, Rings, Age
#
# The Height column data is highly skewed
#
# All the columns are not normallly distributed

# %% [markdown]
# # Correlation

# %%
Abalone_case.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
# Age             0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings       Age
# Length                0.903018      0.897706  0.556720  0.556720
# Diameter              0.899724      0.905330  0.574660  0.574660
# ...

# %%
Abalone_case.corr()['Rings'].sort_values()
# Out:
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Age               1.000000
# Name: Rings, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.heatmap(Abalone_case.corr(),annot=True, linewidth=0.5, linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation

# %% [raw]
# Length has 56% correlation with the target column which can be considered as good bond
# Diameter has 57% correlation with the target column which can be considered as good bond
# Height has 56% correlation with the target column which can be considered as good bond
# Whole weight has 54% correlation with the target column which can be considered as good bond
# Shucked weight has 42% correlation with the target column which can be considered as weak bond
# Viscera weight has 50% correlation with the target column which can be considered as good bond
# Shell weight has 63% correlation with the target column which can be considered as good bond
# Age weight has 1% correlation with the target column which can be considered as strong bond

# %% [markdown]
# Max Correlation: Age
#
# Mean Correlation: Shucked weight

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## Describing Datasets:

# %%
Abalone_case.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings          Age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684    11.433684
# std          0.109614      0.139203     3.224169     3.224169
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(Abalone_case.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.xticks(fontsize=12)
plt.title('variables')
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# # Outcome of Describe of Datasets:

# %% [markdown]
# We are determining Mean, Standard Deviation, Minimum and Maximum Values of each column from the plot which will help in data cleaning
#
# Total No of Rows: 4177 Total No. of Columns: 8
#
# length:

# %% [raw]
# Mean= 0.523992
# std= 0.120093
# Min= 0.075000
# Max= 0.815000

# %% [markdown]
# Diameter:

# %% [raw]
# Mean= 0.407881
# std= 0.099240
# Min= 0.055000
# Max= 0.650000

# %% [markdown]
# Height:

# %% [raw]
# Mean= 0.139516
# std= 0.041827
# Min= 0.000000
# Max= 0.828742

# %% [markdown]
# Whole weight:

# %% [raw]
# Mean= 0.828742
# std= 0.490389
# Min= 0.002000
# Max= 2.825500

# %% [markdown]
# Shucked weight:

# %% [raw]
# Mean= 0.359367
# std= 0.221963
# Min= 0.001000
# Max= 1.488000

# %% [markdown]
# Viscera weight:

# %% [raw]
# Mean= 0.180594
# std= 0.109614
# Min= 0.000500
# Max= 0.760000

# %% [markdown]
# Shell weight:

# %% [raw]
# Mean= 0.238831
# std= 0.139203
# Min= 0.001500
# Max= 1.005000

# %% [markdown]
# Age:

# %% [raw]
# Mean= 11.433684
# std= 3.224169
# Min= 2.500000
# Max= 30.500000

# %% [markdown]
# Rings is Target column and it comes under binary categorical data, so describe shows no valid outcome.

# %%
Abalone_case.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
#  9   Age             4177 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 326.5+ KB

# %% [markdown]
# We have now info about data types and memory usage

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Coverting Sex column data which contains categorical data into continuous data.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
Abalone_case["Sex"].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
Abalone_case['Sex']=encoder.fit_transform(Abalone_case['Sex'])

# %%
Abalone_case["Sex"].unique()
# Out:
# array([2, 0, 1])

# %% [markdown]
# # Checking Outliers

# %%
collist=Abalone_case.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=Abalone_case[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# We can see there is outlier present in all columns except 'Sex' column.

# %% [markdown]
# # Data Cleaning

# %%
Abalone_case.corr()['Rings']
# Out:
# Sex              -0.034627
# Length            0.556720
# Diameter          0.574660
# Height            0.557467
# Whole weight      0.540390
# Shucked weight    0.420884
# Viscera weight    0.503819
# Shell weight      0.627574
# Rings             1.000000
# Age               1.000000
# Name: Rings, dtype: float64

# %%
Abalone_case['Rings'].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24], dtype=int64)

# %% [markdown]
# # Outliers removal with Scipy

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(Abalone_case))
z.shape
# Out:
# (4177, 10)

# %%
z.head()
# Out:
#         Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0  1.151980  0.574558  0.432149  1.064424      0.641898        0.607685
# 1  1.151980  1.448986  1.439929  1.183978      1.230277        1.170910
# 2  1.280690  0.050033  0.122130  0.107991      0.309469        0.463500
# 3  1.151980  0.699476  0.432149  0.347099      0.637819        0.648238
# 4  0.064355  1.615544  1.540707  1.423087      1.272086        1.215968
#
#    Viscera weight  Shell weight     Rings       Age
# 0        0.726212      0.638217  1.571544  1.571544
# 1        1.205221      1.212987  0.910013  0.910013
# 2        0.356690      0.207139  0.289624  0.289624
# 3        0.607600      0.602294  0.020571  0.020571
# 4        1.287337      1.320757  0.910013  0.910013

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,    6,   72,   72,   81,   83,   83,  129,  163,  164,  165,
#         165,  165,  166,  166,  166,  167,  167,  168,  170,  181,  181,
#         232,  232,  236,  236,  236,  237,  237,  238,  238,  239,  270,
#         270,  275,  275,  277,  278,  278,  294,  294,  310,  310,  313,
#         313,  314,  314,  334,  351,  351,  355,  355,  358,  358,  362,
#         362,  375,  375,  416,  416,  417,  417,  428,  428,  431,  431,
#         433,  433,  469,  469,  478,  478,  480,  480,  501,  501,  526,
#         526,  530,  530,  572,  572,  628,  628,  673,  673,  674,  674,
#         675,  675,  678,  678,  694,  696,  696,  719,  719,  720,  720,
#         744,  744,  754,  754,  756,  756,  811,  811,  891,  891,  891,
#        1048, 1051, 1051, 1052, 1193, 1197, 1199, 1202, 1204, 1206, 1206,
#        1207, 1207, 1207, 1207, 1209, 1209, 1257, 1417, 1417, 1418, 1422,
#        1426, 1427, 1427, 1427, 1428, 1429, 1429, 1528, 1754, 1756, 1757,
# ...

# %%
len(np.where(z>3)[0])
# Out:
# 262

# %%
Abalone=Abalone_case[(z<3).all(axis=1)]
Abalone.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings   Age
# 0          0.1010         0.150     15  16.5
# 1          0.0485         0.070      7   8.5
# 2          0.1415         0.210      9  10.5
# 3          0.1140         0.155     10  11.5
# 4          0.0395         0.055      7   8.5

# %%
print("Old DataFrame data in Rows and Column:",Abalone_case.shape)
# Out:
# Old DataFrame data in Rows and Column: (4177, 10)

# %%
print("New DataFrame data in Rows and Column:",Abalone.shape)
# Out:
# New DataFrame data in Rows and Column: (4027, 10)

# %%
print("Total Dropped rows:",Abalone_case.shape[0]-Abalone.shape[0])
# Out:
# Total Dropped rows: 150

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percent=(4177-4027)/4177*100
print(loss_percent,"%")
# Out:
# 3.5910940866650707 %

# %% [markdown]
# # Spliting data into Target and Features:

# %%
x = Abalone.drop("Rings",axis=1)
y = Abalone["Rings"]

# %%
x.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %%
y.head()
# Out:
# 0    15
# 1     7
# 2     9
# 3    10
# 4     7
# Name: Rings, dtype: int64

# %% [markdown]
# # Removing skewness using yeo-johnson method:

# %%
from sklearn.preprocessing  import power_transform

# %%
x=power_transform(Abalone,method='yeo-johnson')
x
# Out:
# array([[ 1.13432919, -0.68445079, -0.54337947, ..., -0.58635376,
#          1.67302767,  1.67200687],
#        [ 1.13432919, -1.4117394 , -1.40113174, ..., -1.33271691,
#         -0.97812692, -0.98122443],
#        [-1.31306782, -0.0462191 ,  0.03716259, ..., -0.08021413,
#         -0.15943946, -0.15898887],
#        ...,
#        [ 1.13432919,  0.65112915,  0.70592133, ...,  0.66363183,
#         -0.15943946, -0.15898887],
#        [-1.31306782,  0.92606411,  0.8377131 , ...,  0.57752029,
#          0.20009181,  0.20199546],
#        [ 1.13432919,  1.9719402 ,  1.85550496, ...,  1.85675543,
#          0.84488768,  0.84778605]])

# %% [markdown]
# Checking skewness is removed or not

# %%
Abalone.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings             0.725464
# Age               0.725464
# dtype: float64

# %% [markdown]
# It looks skewness is removed

# %%
sns.distplot(Abalone['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %% [markdown]
# # Data Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit_transform(x)
x
# Out:
# array([[ 1.13432919, -0.68445079, -0.54337947, ..., -0.58635376,
#          1.67302767,  1.67200687],
#        [ 1.13432919, -1.4117394 , -1.40113174, ..., -1.33271691,
#         -0.97812692, -0.98122443],
#        [-1.31306782, -0.0462191 ,  0.03716259, ..., -0.08021413,
#         -0.15943946, -0.15898887],
#        ...,
#        [ 1.13432919,  0.65112915,  0.70592133, ...,  0.66363183,
#         -0.15943946, -0.15898887],
#        [-1.31306782,  0.92606411,  0.8377131 , ...,  0.57752029,
#          0.20009181,  0.20199546],
#        [ 1.13432919,  1.9719402 ,  1.85550496, ...,  1.85675543,
#          0.84488768,  0.84778605]])

# %%
x.mean()
# Out:
# -1.9550070802636975e-16

# %% [markdown]
# # Creating Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import r2_score

# %% [markdown]
# # Logistic Regression Model

# %%
lr=LogisticRegression()

# %% [markdown]
# # Splitting the DataFrame into train-test-split

# %%
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=i, test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
        print('Logistic Regression model Result are:-' )
        print('At random state' , i, 'the Model performs very well')
        print('At random state:- ' , i)
        print('the training r2 score is:- ', round(r2_score(y_train,pred_train)*100,1))
        print('the testing r2 score is:- ', round(r2_score(y_test,pred_test)*100,1),'\n\n')
# Out:
# Logistic Regression model Result are:-
# At random state 9 the Model performs very well
# At random state:-  9
# the training r2 score is:-  97.9
# the testing r2 score is:-  97.9
#
#
# Logistic Regression model Result are:-
# At random state 40 the Model performs very well
# At random state:-  40
# the training r2 score is:-  98.0
# the testing r2 score is:-  98.0
#
#
# Logistic Regression model Result are:-
# At random state 108 the Model performs very well
# At random state:-  108
# the training r2 score is:-  97.9
# the testing r2 score is:-  97.9
#
#
# Logistic Regression model Result are:-
# At random state 109 the Model performs very well
# At random state:-  109
# the training r2 score is:-  97.7
# the testing r2 score is:-  97.7
#
#
# Logistic Regression model Result are:-
# At random state 111 the Model performs very well
# At random state:-  111
# the training r2 score is:-  97.8
# the testing r2 score is:-  97.8
#
#
# Logistic Regression model Result are:-
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=9, test_size=0.20)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Classification report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00        10
#            5       0.00      0.00      0.00        23
#            6       0.04      0.03      0.03        61
#            7       0.06      0.06      0.06        70
#            8       0.18      0.21      0.19       110
#            9       0.12      0.12      0.12       141
#           10       0.16      0.16      0.16       113
#           11       0.13      0.19      0.16       102
#           12       0.04      0.02      0.02        53
#           13       0.10      0.10      0.10        50
#           14       0.00      0.00      0.00        20
#           15       0.05      0.06      0.06        16
#           16       0.00      0.00      0.00         9
#           17       0.00      0.00      0.00        11
#           18       0.00      0.00      0.00         8
# ...

# %% [markdown]
# # Cross Validation score for Logistic Regression

# %%
from sklearn.model_selection import cross_val_score

# %%
pred_lr=lr.predict(x_test)
lss=r2_score(y_test,pred_lr)

# %%
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print("At cv: ",j)
    print("Cross Validation score is: ",cv_mean*100)
    print("r2_score is: ",lss*100,"\n")
# Out:
# At cv:  2
# Cross Validation score is:  78.44573825250075
# r2_score is:  97.93582210850053
#
# At cv:  3
# Cross Validation score is:  81.3505216835173
# r2_score is:  97.93582210850053
#
# At cv:  4
# Cross Validation score is:  81.99655098209156
# r2_score is:  97.93582210850053
#
# At cv:  5
# Cross Validation score is:  82.29422190712515
# r2_score is:  97.93582210850053
#
# At cv:  6
# Cross Validation score is:  82.7658537955669
# r2_score is:  97.93582210850053
#
# At cv:  7
# Cross Validation score is:  83.03877674258109
# r2_score is:  97.93582210850053
#
# At cv:  8
# Cross Validation score is:  82.98911885827889
# r2_score is:  97.93582210850053
#
# At cv:  9
# Cross Validation score is:  82.81632843293917
# r2_score is:  97.93582210850053

# %%
print('cross_val_score for logistic Regression : ',cross_val_score(lr,x,y,cv=9).mean())
# Out:
# cross_val_score for logistic Regression :  0.8281632843293917

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc=DecisionTreeClassifier()

# %%
dc.fit(x_train,y_train)
pred=dc.predict(x_test)
print('r2 Score for Decision Tree Classifier:',r2_score(y_test,pred))
# Out:
# r2 Score for Decision Tree Classifier: 1.0

# %% [markdown]
# # KNN Regressor Model

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
kn =KNeighborsRegressor()
kn.fit(x_train, y_train)
pred_kn= kn.predict(x_test)
print(' KNN regressor result :-')
print('r2 Score is ',r2_score(pred_test,y_test))
# Out:
#  KNN regressor result :-
# r2 Score is  -1.188844077035728

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('r2 Score:',r2_score(y_test,pred))
# Out:
# r2 Score: 0.9999999541293801

# %% [markdown]
# # Support Vector Regressor:

# %%
from sklearn.svm import SVR

# %%
sv = SVR()
sv.fit(x_train, y_train)
pred_kn= sv.predict(x_test)
print(' KNN regressor result :-')
print('r2 score is ',r2_score(pred_test,y_test))
# Out:
#  KNN regressor result :-
# r2 score is  -1.188844077035728

# %% [markdown]
# # Decision Tree Regressor:

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred=DTR.predict(x_test)
print('r2 Score:',r2_score(y_test,pred))
# Out:
# r2 Score: 1.0

# %% [markdown]
# # Lasso Regression:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Abalone=GridSearchCV(ls,parameters)
Abalone.fit(x_train,y_train)
print(Abalone.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_ls))
# Out:
# R2_Score: 0.9783158854703783

# %% [markdown]
# # Hyper parameter tuning:

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'criterion':["mse","mae","poisson"], 'random_state':[1,10,100,1000], 'max_depth':[4,5,7,8,9], 'max_features':["auto","sqrt","log2"] }

# %%
GCV=GridSearchCV(DecisionTreeRegressor(),parameter,cv=9)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=9, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'mae', 'poisson'],
#                          'max_depth': [4, 5, 7, 8, 9],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'random_state': [1, 10, 100, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse', 'max_depth': 5, 'max_features': 'auto', 'random_state': 1}

# %%
Final_mode=DecisionTreeRegressor(criterion='mse',max_depth=5,max_features='auto',random_state=1)
Final_mode.fit(x_train,y_train)
pred=Final_mode.predict(x_test)
accuracy=r2_score(y_test, pred)

print(accuracy*100)
# Out:
# 100.0

# %% [markdown]
# After tuning my Decision Tree Regressor model using Grid Search CV i got my final model accuracy as 100%

# %% [markdown]
# # Saving the Model

# %%
import pickle
filename='Abalone_case_study.pickle'
pickle.dump(rf,open(filename,'wb'))
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model.predict(x_test)
# Out:
# array([ 7.  ,  8.  ,  9.  , 18.  , 10.  , 13.  ,  9.  , 15.  ,  8.  ,
#         6.  ,  9.  ,  8.  , 19.  ,  8.  ,  9.  ,  8.  ,  6.  ,  9.  ,
#        11.  , 17.  ,  8.  ,  6.  , 13.  , 10.  ,  7.  , 12.  ,  8.  ,
#        10.  ,  7.  , 13.  , 10.  , 11.  ,  7.  , 10.  , 15.  ,  8.  ,
#        11.  , 11.  ,  8.  , 14.  ,  9.  ,  7.  ,  8.  , 13.  ,  9.  ,
#         7.  , 10.  , 10.  , 12.  ,  8.  , 10.  ,  8.  , 13.  , 10.  ,
#        10.  ,  8.  ,  9.  , 17.  , 10.  , 11.  ,  8.  ,  9.  ,  9.  ,
#        10.  , 11.  , 12.  ,  9.  , 13.  ,  7.  , 11.  ,  9.  ,  9.  ,
#        11.  ,  7.  ,  8.  , 19.  , 18.  ,  6.  ,  8.  ,  9.  ,  8.  ,
#         6.  ,  9.  ,  6.  ,  9.  , 10.  ,  7.  ,  8.  ,  6.  , 12.  ,
#         8.  ,  8.  , 11.  ,  7.  , 13.  ,  7.  , 13.  , 10.  , 11.  ,
#         8.  , 11.  ,  8.  , 11.  , 16.  , 10.  ,  9.  ,  8.  ,  6.  ,
#         6.  , 10.  ,  8.  ,  7.  , 10.  , 10.  , 10.  ,  8.  ,  9.  ,
# ...

# %%
a =np.array(y_test)
predicted=np.array(rf.predict(x_test))
Abalone=pd.DataFrame({'Orginal':a,'Predicted':predicted}, index=range(len(a)))
Abalone
# Out:
#      Orginal  Predicted
# 0          7        7.0
# 1          8        8.0
# 2          9        9.0
# 3         18       18.0
# 4         10       10.0
# ..       ...        ...
# 801       10       10.0
# 802        9        9.0
# 803       12       12.0
# 804       15       15.0
# 805        4        4.0
#
# [806 rows x 2 columns]

# %% [markdown]
# # As we can see, predicted and original values matches 100%.
